// %%
%mavenRepo vendredi https://repository.hellonico.info/repository/hellonico/

// %%
%maven origami:origami:4.2.0-0

// %%
import org.opencv.core.Core;
import org.opencv.core.CvType;
import org.opencv.core.Mat;
import org.opencv.imgcodecs.Imgcodecs;
import origami.Origami;

// %%
Origami.init();
Mat.eye(3, 3, CvType.CV_8UC1).dump();
// Out:
// Already loaded:opencv_java420
// [  1,   0,   0;
//    0,   1,   0;
//    0,   0,   1]

// %%
Core.VERSION
// Out:
// 4.2.0

// %%
Mat source = Imgcodecs.imread("resources/digital_image_processing.jpg");
Mat destination = new Mat(source.rows(), source.cols(), source.type());
double alpha = 2;
double beta = 50;
source.convertTo(destination, -1, alpha, beta);

// %%
Origami.matToBufferedImage(destination);
// Out:
// BufferedImage@409d93b6: type = 5 ColorModel: #pixelBits = 24 numComponents = 3 color space = java.awt.color.ICC_ColorSpace@65482277 transparency = 1 has alpha = false isAlphaPre = false ByteInterleavedRaster: width = 500 height = 360 #numDataElements 3 dataOff[0] = 2
